# %% [markdown]
# # Data Visualizations

# %%
# %matplotlib inline
# import required libraries
import random
import datetime 
import numpy as np
import pandas as pd
from random import randrange

import matplotlib.pyplot as plt

import seaborn as sns

sns.set_style('whitegrid')
sns.set_context('talk')

params = {'legend.fontsize': 'small',
          'figure.figsize': (30, 10),
         'axes.labelsize': 'medium',
         'axes.titlesize':'medium',
         'xtick.labelsize':'medium',
         'ytick.labelsize':'medium'}

plt.rcParams.update(params)

from IPython.display import display, HTML

# %%
Bigmart_Sales = pd.read_csv("BigmartSales.csv")

# %%
Bigmart_Sales.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           NCE42          NaN          Low Fat         0.010551
# 1           FDQ19          NaN          Regular         0.014296
# 2           FDZ20          NaN          Low Fat         0.000000
# 3           FDP33          NaN          Low Fat         0.088840
# 4           FDI50          NaN          Regular         0.030693
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0              Household  234.9958            OUT027
# 1  Fruits and Vegetables  242.6512            OUT027
# 2  Fruits and Vegetables  253.0356            OUT027
# 3            Snack Foods  254.2672            OUT027
# 4                 Canned  228.0352            OUT027
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1985      Medium               Tier 3
# 1                       1985      Medium               Tier 3
# ...

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ### Line Charts

# %%
Sales = Bigmart_Sales['Item_MRP']
Sales.plot()

# %%
max_Item_Identifier = Bigmart_Sales.Item_Identifier.value_counts().index[0]
Bigmart_Sales[Bigmart_Sales.Item_Identifier == max_Item_Identifier][['Item_MRP']].plot(style='blue')
plt.title('Price Trends for Particular User')
plt.show()

# %% [markdown]
# ### Bar Charts

# %%
Bigmart_Sales.Outlet_Establishment_Year.hist(color='coral')
plt.title('Outlet Establishment')
plt.show()

# %% [markdown]
# ### Pie Chart

# %%
class_series = Bigmart_Sales.groupby('Item_Type').size()
class_series.name = ""
class_series.plot.pie()
plt.show()
